# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\PcSrv\Documents\Python Scripts\Datasets\Dota 2 -HEROES\heroes_data.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  id                          name  localized_name primary_attr  \
# 0           0   1        npc_dota_hero_antimage       Anti-Mage          agi
# 1           1   2             npc_dota_hero_axe             Axe          str
# 2           2   3            npc_dota_hero_bane            Bane          int
# 3           3   4     npc_dota_hero_bloodseeker     Bloodseeker          agi
# 4           4   5  npc_dota_hero_crystal_maiden  Crystal Maiden          int
#
#   attack_type                                              roles  \
# 0       Melee                       ['Carry', 'Escape', 'Nuker']
# 1       Melee    ['Initiator', 'Durable', 'Disabler', 'Jungler']
# 2      Ranged        ['Support', 'Disabler', 'Nuker', 'Durable']
# 3       Melee  ['Carry', 'Disabler', 'Jungler', 'Nuker', 'Ini...
# 4      Ranged        ['Support', 'Disabler', 'Nuker', 'Jungler']
#
#                                                  img  \
# 0       /apps/dota2/images/heroes/antimage_full.png?
# ...

# %%
pd.set_option('display.max_colwidth', 1000)

# %%
df.shape
# Out:
# (120, 55)

# %%
pd.set_option('display.max_column', 500)

# %%
df.head()
# Out:
#    Unnamed: 0  id                          name  localized_name primary_attr  \
# 0           0   1        npc_dota_hero_antimage       Anti-Mage          agi
# 1           1   2             npc_dota_hero_axe             Axe          str
# 2           2   3            npc_dota_hero_bane            Bane          int
# 3           3   4     npc_dota_hero_bloodseeker     Bloodseeker          agi
# 4           4   5  npc_dota_hero_crystal_maiden  Crystal Maiden          int
#
#   attack_type                                                   roles  \
# 0       Melee                            ['Carry', 'Escape', 'Nuker']
# 1       Melee         ['Initiator', 'Durable', 'Disabler', 'Jungler']
# 2      Ranged             ['Support', 'Disabler', 'Nuker', 'Durable']
# 3       Melee  ['Carry', 'Disabler', 'Jungler', 'Nuker', 'Initiator']
# 4      Ranged             ['Support', 'Disabler', 'Nuker', 'Jungler']
#
#                                                   img  \
# ...

# %%
df.isna().sum()
# Out:
# Unnamed: 0            0
# id                    0
# name                  0
# localized_name        0
# primary_attr          0
# attack_type           0
# roles                 0
# img                   0
# icon                  0
# base_health           0
# base_health_regen    76
# base_mana             0
# base_mana_regen       0
# base_armor            0
# base_mr               0
# base_attack_min       0
# base_attack_max       0
# base_str              0
# base_agi              0
# base_int              0
# str_gain              0
# agi_gain              0
# int_gain              0
# attack_range          0
# projectile_speed      0
# attack_rate           0
# move_speed            0
# turn_rate             0
# cm_enabled            0
# legs                  0
# hero_id               0
# turbo_picks           0
# turbo_wins            0
# pro_ban               0
# pro_win               0
# pro_pick              0
# 1_pick                0
# 1_win                 0
# ...

# %%
df.dtypes
# Out:
# Unnamed: 0             int64
# id                     int64
# name                  object
# localized_name        object
# primary_attr          object
# attack_type           object
# roles                 object
# img                   object
# icon                  object
# base_health            int64
# base_health_regen    float64
# base_mana              int64
# base_mana_regen      float64
# base_armor           float64
# base_mr                int64
# base_attack_min        int64
# base_attack_max        int64
# base_str               int64
# base_agi               int64
# base_int               int64
# str_gain             float64
# agi_gain             float64
# int_gain             float64
# attack_range           int64
# projectile_speed       int64
# attack_rate          float64
# move_speed             int64
# turn_rate            float64
# cm_enabled              bool
# legs                   int64
# hero_id                int64
# turbo_picks            int64
# ...

# %%
pd.set_option('display.max_rows', 500)

# %%
df
# Out:
#      Unnamed: 0   id                               name       localized_name  \
# 0             0    1             npc_dota_hero_antimage            Anti-Mage
# 1             1    2                  npc_dota_hero_axe                  Axe
# 2             2    3                 npc_dota_hero_bane                 Bane
# 3             3    4          npc_dota_hero_bloodseeker          Bloodseeker
# 4             4    5       npc_dota_hero_crystal_maiden       Crystal Maiden
# 5             5    6          npc_dota_hero_drow_ranger          Drow Ranger
# 6             6    7          npc_dota_hero_earthshaker          Earthshaker
# 7             7    8           npc_dota_hero_juggernaut           Juggernaut
# 8             8    9               npc_dota_hero_mirana               Mirana
# 9             9   10            npc_dota_hero_morphling            Morphling
# 10           10   11            npc_dota_hero_nevermore         Shadow Fiend
# ...

# %%
df[df.localized_name.str.contains('-','_')]
# Out:
#    Unnamed: 0  id                    name localized_name primary_attr  \
# 0           0   1  npc_dota_hero_antimage      Anti-Mage          agi
#
#   attack_type                         roles  \
# 0       Melee  ['Carry', 'Escape', 'Nuker']
#
#                                             img  \
# 0  /apps/dota2/images/heroes/antimage_full.png?
#
#                                           icon  base_health  \
# 0  /apps/dota2/images/heroes/antimage_icon.png          200
#
#    base_health_regen  base_mana  base_mana_regen  base_armor  base_mr  \
# 0               0.25         75              0.0        -1.0       25
#
#    base_attack_min  base_attack_max  base_str  base_agi  base_int  str_gain  \
# 0               29               33        23        24        12       1.3
#
#    agi_gain  int_gain  attack_range  projectile_speed  attack_rate  \
# 0       2.8       1.8           150                 0          1.4
#
# ...

# %%
df = df.drop(['name', 'img', 'icon'], axis = 1).set_index('id')

# %%
df.head()
# Out:
#     Unnamed: 0  localized_name primary_attr attack_type  \
# id
# 1            0       Anti-Mage          agi       Melee
# 2            1             Axe          str       Melee
# 3            2            Bane          int      Ranged
# 4            3     Bloodseeker          agi       Melee
# 5            4  Crystal Maiden          int      Ranged
#
#                                                      roles  base_health  \
# id
# 1                             ['Carry', 'Escape', 'Nuker']          200
# 2          ['Initiator', 'Durable', 'Disabler', 'Jungler']          200
# 3              ['Support', 'Disabler', 'Nuker', 'Durable']          200
# 4   ['Carry', 'Disabler', 'Jungler', 'Nuker', 'Initiator']          200
# 5              ['Support', 'Disabler', 'Nuker', 'Jungler']          200
#
#     base_health_regen  base_mana  base_mana_regen  base_armor  base_mr  \
# id
# 1                0.25         75              0.0        -1.0       25
# ...

# %%
df = df.iloc[:, 1:]

# %%
df.head()
# Out:
#     localized_name primary_attr attack_type  \
# id
# 1        Anti-Mage          agi       Melee
# 2              Axe          str       Melee
# 3             Bane          int      Ranged
# 4      Bloodseeker          agi       Melee
# 5   Crystal Maiden          int      Ranged
#
#                                                      roles  base_health  \
# id
# 1                             ['Carry', 'Escape', 'Nuker']          200
# 2          ['Initiator', 'Durable', 'Disabler', 'Jungler']          200
# 3              ['Support', 'Disabler', 'Nuker', 'Durable']          200
# 4   ['Carry', 'Disabler', 'Jungler', 'Nuker', 'Initiator']          200
# 5              ['Support', 'Disabler', 'Nuker', 'Jungler']          200
#
#     base_health_regen  base_mana  base_mana_regen  base_armor  base_mr  \
# id
# 1                0.25         75              0.0        -1.0       25
# 2                2.75         75              0.0        -1.0       25
# ...

# %%
df.base_health_regen.mean(numeric_only = True)
# Out:
# 0.9602272727272727

# %%
df.base_health_regen = df.base_health_regen.fillna('0.96')

# %%
df.isna().sum()
# Out:
# localized_name       0
# primary_attr         0
# attack_type          0
# roles                0
# base_health          0
# base_health_regen    0
# base_mana            0
# base_mana_regen      0
# base_armor           0
# base_mr              0
# base_attack_min      0
# base_attack_max      0
# base_str             0
# base_agi             0
# base_int             0
# str_gain             0
# agi_gain             0
# int_gain             0
# attack_range         0
# projectile_speed     0
# attack_rate          0
# move_speed           0
# turn_rate            0
# cm_enabled           0
# legs                 0
# hero_id              0
# turbo_picks          0
# turbo_wins           0
# pro_ban              0
# pro_win              0
# pro_pick             0
# 1_pick               0
# 1_win                0
# 2_pick               0
# 2_win                0
# 3_pick               0
# 3_win                0
# 4_pick               0
# 4_win                0
# 5_pick               0
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.head()
# Out:
#     localized_name primary_attr attack_type  \
# id
# 1        Anti-Mage          agi       Melee
# 2              Axe          str       Melee
# 3             Bane          int      Ranged
# 4      Bloodseeker          agi       Melee
# 5   Crystal Maiden          int      Ranged
#
#                                                      roles  base_health  \
# id
# 1                             ['Carry', 'Escape', 'Nuker']          200
# 2          ['Initiator', 'Durable', 'Disabler', 'Jungler']          200
# 3              ['Support', 'Disabler', 'Nuker', 'Durable']          200
# 4   ['Carry', 'Disabler', 'Jungler', 'Nuker', 'Initiator']          200
# 5              ['Support', 'Disabler', 'Nuker', 'Jungler']          200
#
#    base_health_regen  base_mana  base_mana_regen  base_armor  base_mr  \
# id
# 1               0.25         75              0.0        -1.0       25
# 2               2.75         75              0.0        -1.0       25
# ...

# %%
df.roles = df.roles.str.replace('[','').str.replace(']','')

# %%
df.head()
# Out:
#     localized_name primary_attr attack_type  \
# id
# 1        Anti-Mage          agi       Melee
# 2              Axe          str       Melee
# 3             Bane          int      Ranged
# 4      Bloodseeker          agi       Melee
# 5   Crystal Maiden          int      Ranged
#
#                                                    roles  base_health  \
# id
# 1                             'Carry', 'Escape', 'Nuker'          200
# 2          'Initiator', 'Durable', 'Disabler', 'Jungler'          200
# 3              'Support', 'Disabler', 'Nuker', 'Durable'          200
# 4   'Carry', 'Disabler', 'Jungler', 'Nuker', 'Initiator'          200
# 5              'Support', 'Disabler', 'Nuker', 'Jungler'          200
#
#    base_health_regen  base_mana  base_mana_regen  base_armor  base_mr  \
# id
# 1               0.25         75              0.0        -1.0       25
# 2               2.75         75              0.0        -1.0       25
# ...

# %%
df = df.rename({'localized_name': 'Hero'}, axis = 1)

# %%
df.head()
# Out:
#               Hero primary_attr attack_type  \
# id
# 1        Anti-Mage          agi       Melee
# 2              Axe          str       Melee
# 3             Bane          int      Ranged
# 4      Bloodseeker          agi       Melee
# 5   Crystal Maiden          int      Ranged
#
#                                                    roles  base_health  \
# id
# 1                             'Carry', 'Escape', 'Nuker'          200
# 2          'Initiator', 'Durable', 'Disabler', 'Jungler'          200
# 3              'Support', 'Disabler', 'Nuker', 'Durable'          200
# 4   'Carry', 'Disabler', 'Jungler', 'Nuker', 'Initiator'          200
# 5              'Support', 'Disabler', 'Nuker', 'Jungler'          200
#
#    base_health_regen  base_mana  base_mana_regen  base_armor  base_mr  \
# id
# 1               0.25         75              0.0        -1.0       25
# 2               2.75         75              0.0        -1.0       25
# ...

# %%
df.roles = df.roles.str.replace(',', '')

# %%
df.head()
# Out:
#               Hero primary_attr attack_type  \
# id
# 1        Anti-Mage          agi       Melee
# 2              Axe          str       Melee
# 3             Bane          int      Ranged
# 4      Bloodseeker          agi       Melee
# 5   Crystal Maiden          int      Ranged
#
#                                                roles  base_health  \
# id
# 1                           'Carry' 'Escape' 'Nuker'          200
# 2         'Initiator' 'Durable' 'Disabler' 'Jungler'          200
# 3             'Support' 'Disabler' 'Nuker' 'Durable'          200
# 4   'Carry' 'Disabler' 'Jungler' 'Nuker' 'Initiator'          200
# 5             'Support' 'Disabler' 'Nuker' 'Jungler'          200
#
#    base_health_regen  base_mana  base_mana_regen  base_armor  base_mr  \
# id
# 1               0.25         75              0.0        -1.0       25
# 2               2.75         75              0.0        -1.0       25
# 3               0.96         75              0.0         1.0       25
# ...

# %%
df.groupby('roles').winrate.mean().sort_values(ascending = False)
# Out:
# roles
# 'Carry' 'Pusher' 'Jungler' 'Durable' 'Escape'                  57.515265
# 'Carry' 'Pusher' 'Escape' 'Nuker'                              56.858526
# 'Carry' 'Escape' 'Pusher'                                      56.592634
# 'Disabler' 'Jungler' 'Initiator' 'Pusher'                      55.779958
# 'Support' 'Nuker' 'Durable' 'Disabler' 'Pusher'                54.624909
# 'Escape' 'Nuker'                                               54.090909
# 'Support' 'Jungler' 'Pusher'                                   53.973013
# 'Support' 'Pusher' 'Disabler' 'Nuker' 'Initiator'              53.372913
# 'Disabler' 'Nuker' 'Initiator' 'Escape'                        53.175283
# 'Initiator' 'Jungler' 'Escape' 'Disabler'                      53.053578
# 'Initiator' 'Disabler' 'Durable' 'Nuker'                       52.876832
# 'Carry' 'Support' 'Durable' 'Disabler' 'Initiator' 'Nuker'     52.710377
# 'Support' 'Disabler' 'Nuker' 'Durable'                         52.691740
# ...

# %%
df.roles = df.roles.str.replace("'", "").str.replace(' ','_')

# %%
df.roles.sort_values( kind = 'stable')
# Out:
# id
# 94                              Carry_Disabler_Durable
# 81             Carry_Disabler_Durable_Pusher_Initiator
# 18              Carry_Disabler_Initiator_Durable_Nuker
# 69              Carry_Disabler_Initiator_Durable_Nuker
# 104             Carry_Disabler_Initiator_Durable_Nuker
# 4               Carry_Disabler_Jungler_Nuker_Initiator
# 6                                Carry_Disabler_Pusher
# 67                                Carry_Durable_Escape
# 59                             Carry_Durable_Initiator
# 47                    Carry_Durable_Initiator_Disabler
# 28             Carry_Durable_Initiator_Disabler_Escape
# 99                       Carry_Durable_Initiator_Nuker
# 54               Carry_Durable_Jungler_Escape_Disabler
# 15                          Carry_Durable_Nuker_Pusher
# 44                                        Carry_Escape
# 46                                        Carry_Escape
# 63                                        Carry_Escape
# ...

# %%
df[df.roles.isin(['Carry_Durable_Escape'])]
# Out:
#        Hero primary_attr attack_type                 roles  base_health  \
# id
# 67  Spectre          agi       Melee  Carry_Durable_Escape          200
#
#    base_health_regen  base_mana  base_mana_regen  base_armor  base_mr  \
# id
# 67               1.5         75              0.0         0.0       25
#
#     base_attack_min  base_attack_max  base_str  base_agi  base_int  str_gain  \
# id
# 67               23               27        23        23        16       2.5
#
#     agi_gain  int_gain  attack_range  projectile_speed  attack_rate  \
# id
# 67       2.1       1.9           150               900          1.7
#
#     move_speed  turn_rate  cm_enabled  legs  hero_id  turbo_picks  turbo_wins  \
# id
# 67         290        0.5        True     0       67        23640       13026
#
#     pro_ban  pro_win  pro_pick  1_pick  1_win  2_pick  2_win  3_pick  3_win  \
# id
# 67       22        1         9   10684   5777   24236  12528   34011  17648
#
# ...

# %%
df[df.roles.isin(['Pusher'])]
# Out:
# Empty DataFrame
# Columns: [Hero, primary_attr, attack_type, roles, base_health, base_health_regen, base_mana, base_mana_regen, base_armor, base_mr, base_attack_min, base_attack_max, base_str, base_agi, base_int, str_gain, agi_gain, int_gain, attack_range, projectile_speed, attack_rate, move_speed, turn_rate, cm_enabled, legs, hero_id, turbo_picks, turbo_wins, pro_ban, pro_win, pro_pick, 1_pick, 1_win, 2_pick, 2_win, 3_pick, 3_win, 4_pick, 4_win, 5_pick, 5_win, 6_pick, 6_win, 7_pick, 7_win, 8_pick, 8_win, winrate, lane, main_role]
# Index: []

# %%
df.groupby('roles').winrate.mean().sort_values(ascending = False)
# Out:
# roles
# Carry_Pusher_Jungler_Durable_Escape                57.515265
# Carry_Pusher_Escape_Nuker                          56.858526
# Carry_Escape_Pusher                                56.592634
# Disabler_Jungler_Initiator_Pusher                  55.779958
# Support_Nuker_Durable_Disabler_Pusher              54.624909
# Escape_Nuker                                       54.090909
# Support_Jungler_Pusher                             53.973013
# Support_Pusher_Disabler_Nuker_Initiator            53.372913
# Disabler_Nuker_Initiator_Escape                    53.175283
# Initiator_Jungler_Escape_Disabler                  53.053578
# Initiator_Disabler_Durable_Nuker                   52.876832
# Carry_Support_Durable_Disabler_Initiator_Nuker     52.710377
# Support_Disabler_Nuker_Durable                     52.691740
# Carry_Durable_Nuker_Pusher                         52.611012
# Support_Nuker_Disabler_Durable_Escape              52.316176
# ...

# %%
df[df.roles.isin(['Carry_Escape_Pusher'])]
# Out:
#       Hero primary_attr attack_type                roles  base_health  \
# id
# 56  Clinkz          agi      Ranged  Carry_Escape_Pusher          200
#
#    base_health_regen  base_mana  base_mana_regen  base_armor  base_mr  \
# id
# 56              0.25         75              0.0         0.0       25
#
#     base_attack_min  base_attack_max  base_str  base_agi  base_int  str_gain  \
# id
# 56               15               21        14        22        18       2.2
#
#     agi_gain  int_gain  attack_range  projectile_speed  attack_rate  \
# id
# 56       2.7       2.2           625               900          1.7
#
#     move_speed  turn_rate  cm_enabled  legs  hero_id  turbo_picks  turbo_wins  \
# id
# 56         290        0.5        True     2       56        36944       20085
#
#     pro_ban  pro_win  pro_pick  1_pick  1_win  2_pick  2_win  3_pick  3_win  \
# id
# 56       21        4         9   10928   5572   19171   9816   22445  11854
#
# ...

# %%
df[df.roles.isin(['Carry_Pusher_Jungler_Durable_Escape'])]
# Out:
#      Hero primary_attr attack_type                                roles  \
# id
# 77  Lycan          str       Melee  Carry_Pusher_Jungler_Durable_Escape
#
#     base_health base_health_regen  base_mana  base_mana_regen  base_armor  \
# id
# 77          200              0.96         75              0.0        -1.0
#
#     base_mr  base_attack_min  base_attack_max  base_str  base_agi  base_int  \
# id
# 77       25               24               29        26        16        23
#
#     str_gain  agi_gain  int_gain  attack_range  projectile_speed  attack_rate  \
# id
# 77       3.4       1.0       1.4           150               900          1.7
#
#     move_speed  turn_rate  cm_enabled  legs  hero_id  turbo_picks  turbo_wins  \
# id
# 77         305        0.5        True     2       77         7850        3468
#
#     pro_ban  pro_win  pro_pick  1_pick  1_win  2_pick  2_win  3_pick  3_win  \
# id
# 77      464       67       111    3189   1435    6489   3065    8671   4164
#
# ...

# %%
df[df.roles.isin(['Carry_Pusher_Escape_Nuker'])]
# Out:
#            Hero primary_attr attack_type                      roles  \
# id
# 61  Broodmother          agi       Melee  Carry_Pusher_Escape_Nuker
#
#     base_health base_health_regen  base_mana  base_mana_regen  base_armor  \
# id
# 61          200              0.96         75              0.0         0.0
#
#     base_mr  base_attack_min  base_attack_max  base_str  base_agi  base_int  \
# id
# 61       25               29               35        18        15        18
#
#     str_gain  agi_gain  int_gain  attack_range  projectile_speed  attack_rate  \
# id
# 61       3.2       3.0       2.0           150               900          1.7
#
#     move_speed  turn_rate  cm_enabled  legs  hero_id  turbo_picks  turbo_wins  \
# id
# 61         275        0.5        True     8       61         6766        2850
#
#     pro_ban  pro_win  pro_pick  1_pick  1_win  2_pick  2_win  3_pick  3_win  \
# id
# 61       68       14        19    2783   1199    4559   2148    5588   2748
#
# ...

# %%
df[df.roles.isin(['Disabler_Jungler_Initiator_Pusher'])]
# Out:
#       Hero primary_attr attack_type                              roles  \
# id
# 33  Enigma          int      Ranged  Disabler_Jungler_Initiator_Pusher
#
#     base_health base_health_regen  base_mana  base_mana_regen  base_armor  \
# id
# 33          200              0.96         75              0.0         2.0
#
#     base_mr  base_attack_min  base_attack_max  base_str  base_agi  base_int  \
# id
# 33       25               24               30        21        14        19
#
#     str_gain  agi_gain  int_gain  attack_range  projectile_speed  attack_rate  \
# id
# 33       2.5       1.0       3.6           500               900          1.7
#
#     move_speed  turn_rate  cm_enabled  legs  hero_id  turbo_picks  turbo_wins  \
# id
# 33         290        0.5        True     0       33        26732       14517
#
#     pro_ban  pro_win  pro_pick  1_pick  1_win  2_pick  2_win  3_pick  3_win  \
# id
# 33      170       54       120    6064   3203   14837   7750   21500  11280
#
# ...

# %%
df[df.roles.isin(['Support_Nuker_Durable_Disabler_Pusher'])]
# Out:
#       Hero primary_attr attack_type                                  roles  \
# id
# 92  Visage          int      Ranged  Support_Nuker_Durable_Disabler_Pusher
#
#     base_health base_health_regen  base_mana  base_mana_regen  base_armor  \
# id
# 92          200              0.96         75              0.0        -2.0
#
#     base_mr  base_attack_min  base_attack_max  base_str  base_agi  base_int  \
# id
# 92       25               23               33        22        11        22
#
#     str_gain  agi_gain  int_gain  attack_range  projectile_speed  attack_rate  \
# id
# 92       2.8       1.3       2.9           600              1400          1.7
#
#     move_speed  turn_rate  cm_enabled  legs  hero_id  turbo_picks  turbo_wins  \
# id
# 92         285        0.5        True     2       92         5301        2478
#
#     pro_ban  pro_win  pro_pick  1_pick  1_win  2_pick  2_win  3_pick  3_win  \
# id
# 92       18        6        16    1230    576    2238   1072    3314   1623
#
# ...

# %%
df[df.roles.isin(['Escape_Nuker'])]
# Out:
#              Hero primary_attr attack_type         roles  base_health  \
# id
# 62  Bounty Hunter          agi       Melee  Escape_Nuker          200
#
#    base_health_regen  base_mana  base_mana_regen  base_armor  base_mr  \
# id
# 62              1.25         75              0.5         4.0       25
#
#     base_attack_min  base_attack_max  base_str  base_agi  base_int  str_gain  \
# id
# 62               30               38        20        21        22       2.5
#
#     agi_gain  int_gain  attack_range  projectile_speed  attack_rate  \
# id
# 62       2.6       1.9           150               900          1.7
#
#     move_speed  turn_rate  cm_enabled  legs  hero_id  turbo_picks  turbo_wins  \
# id
# 62         320        0.6        True     2       62        37474       17924
#
#     pro_ban  pro_win  pro_pick  1_pick  1_win  2_pick  2_win  3_pick  3_win  \
# id
# 62       17       25        47   16864   8556   29609  15320   39718  20842
#
# ...

# %%
df.head()
# Out:
#               Hero primary_attr attack_type  \
# id
# 1        Anti-Mage          agi       Melee
# 2              Axe          str       Melee
# 3             Bane          int      Ranged
# 4      Bloodseeker          agi       Melee
# 5   Crystal Maiden          int      Ranged
#
#                                      roles  base_health base_health_regen  \
# id
# 1                       Carry_Escape_Nuker          200              0.25
# 2       Initiator_Durable_Disabler_Jungler          200              2.75
# 3           Support_Disabler_Nuker_Durable          200              0.96
# 4   Carry_Disabler_Jungler_Nuker_Initiator          200              0.96
# 5           Support_Disabler_Nuker_Jungler          200              0.96
#
#     base_mana  base_mana_regen  base_armor  base_mr  base_attack_min  \
# id
# 1          75              0.0        -1.0       25               29
# 2          75              0.0        -1.0       25               27
# ...

# %%
df.Hero = df.Hero.str.replace(' ','_')

# %%
df.head()
# Out:
#               Hero primary_attr attack_type  \
# id
# 1        Anti-Mage          agi       Melee
# 2              Axe          str       Melee
# 3             Bane          int      Ranged
# 4      Bloodseeker          agi       Melee
# 5   Crystal_Maiden          int      Ranged
#
#                                      roles  base_health base_health_regen  \
# id
# 1                       Carry_Escape_Nuker          200              0.25
# 2       Initiator_Durable_Disabler_Jungler          200              2.75
# 3           Support_Disabler_Nuker_Durable          200              0.96
# 4   Carry_Disabler_Jungler_Nuker_Initiator          200              0.96
# 5           Support_Disabler_Nuker_Jungler          200              0.96
#
#     base_mana  base_mana_regen  base_armor  base_mr  base_attack_min  \
# id
# 1          75              0.0        -1.0       25               29
# 2          75              0.0        -1.0       25               27
# ...

# %%
df.to_csv('Info for Heroes.csv')

# %%
df = df.loc[:, ['Hero','primary_attr', 'attack_type', 'roles', 'winrate', 'lane', 'main_role']]

# %%
df.head()
# Out:
#               Hero primary_attr attack_type  \
# id
# 1        Anti-Mage          agi       Melee
# 2              Axe          str       Melee
# 3             Bane          int      Ranged
# 4      Bloodseeker          agi       Melee
# 5   Crystal_Maiden          int      Ranged
#
#                                      roles    winrate  lane     main_role
# id
# 1                       Carry_Escape_Nuker  47.867144     1      safelane
# 2       Initiator_Durable_Disabler_Jungler  48.711569     3       offlane
# 3           Support_Disabler_Nuker_Durable  52.691740     5  hard_support
# 4   Carry_Disabler_Jungler_Nuker_Initiator  49.400120     1      safelane
# 5           Support_Disabler_Nuker_Jungler  49.860973     5  hard_support

# %%
df = df[df.Hero.isin(['Warlock', 'Skywrath_Mage', 'Invoker', 'Lich', 'Arc_Warden', 'Abaddon', 'Silencer', 'Bane',
                'Dark_Seer', 'Shadow_Demon', 'Leshrac', 'Grimstroke', 'Outworld_Devourer'])]

# %%
df
# Out:
#                   Hero primary_attr attack_type  \
# id
# 3                 Bane          int      Ranged
# 31                Lich          int      Ranged
# 37             Warlock          int      Ranged
# 52             Leshrac          int      Ranged
# 55           Dark_Seer          int       Melee
# 74             Invoker          int      Ranged
# 75            Silencer          int      Ranged
# 76   Outworld_Devourer          int      Ranged
# 79        Shadow_Demon          int      Ranged
# 101      Skywrath_Mage          int      Ranged
# 102            Abaddon          str       Melee
# 113         Arc_Warden          agi      Ranged
# 121         Grimstroke          int      Ranged
#
#                                       roles    winrate  lane     main_role
# id
# 3            Support_Disabler_Nuker_Durable  52.691740     5  hard_support
# 31                            Support_Nuker  48.469007     5  hard_support
# ...

# %%
df.shape
# Out:
# (13, 7)

# %%
df.dtypes
# Out:
# Hero             object
# primary_attr     object
# attack_type      object
# roles            object
# winrate         float64
# lane              int64
# main_role        object
# dtype: object

# %%
df[df.winrate > df.winrate.mean()]
# Out:
#                   Hero primary_attr attack_type  \
# id
# 3                 Bane          int      Ranged
# 37             Warlock          int      Ranged
# 55           Dark_Seer          int       Melee
# 74             Invoker          int      Ranged
# 76   Outworld_Devourer          int      Ranged
# 102            Abaddon          str       Melee
# 113         Arc_Warden          agi      Ranged
#
#                                   roles    winrate  lane     main_role
# id
# 3        Support_Disabler_Nuker_Durable  52.691740     5  hard_support
# 37           Support_Initiator_Disabler  52.304394     5  hard_support
# 55    Initiator_Jungler_Escape_Disabler  53.053578     3       offlane
# 74   Carry_Nuker_Disabler_Escape_Pusher  51.781299     2           mid
# 76                 Carry_Nuker_Disabler  50.608638     2           mid
# 102               Support_Carry_Durable  51.749611     4       support
# 113                  Carry_Escape_Nuker  50.943396     2           mid

# %%
df.groupby('lane').winrate.mean()
# Out:
# lane
# 2    50.736434
# 3    53.053578
# 4    49.624832
# 5    49.423554
# Name: winrate, dtype: float64

# %%
df.groupby('roles').winrate.mean().sort_values(ascending = False)
# Out:
# roles
# Initiator_Jungler_Escape_Disabler         53.053578
# Support_Disabler_Nuker_Durable            52.691740
# Support_Initiator_Disabler                52.304394
# Carry_Nuker_Disabler_Escape_Pusher        51.781299
# Support_Carry_Durable                     51.749611
# Carry_Escape_Nuker                        50.943396
# Carry_Nuker_Disabler                      50.608638
# Carry_Support_Nuker_Pusher_Disabler       49.612403
# Support_Nuker_Disabler                    49.199418
# Support_Nuker                             48.469007
# Carry_Support_Disabler_Initiator_Nuker    47.925466
# Support_Disabler_Initiator_Nuker          47.061995
# Support_Nuker_Disabler_Escape             46.590636
# Name: winrate, dtype: float64

# %%
Quality = pd.read_csv(r'C:\Users\PcSrv\Documents\Python Scripts\Heroes_Quality.csv')

# %%
Quality.head()
# Out:
#                 Hero  Health_base  Health_lvl1  Health_lvl15  Health_lvl25  \
# 0  Outworld_Devourer          200          620          1420          2000
# 1         Grimstroke          200          620          1280          1760
# 2            Leshrac          200          600          1300          1800
# 3       Shadow_Demon          200          660          1380          1900
# 4          Dark_Seer          200          600          1460          2080
#
#    Health_lvl30  Health regen_base  Health regen_lvl1  Health regen_lvl15  \
# 0          2300                0.0                2.1                6.16
# 1          2000                0.0                2.1                5.46
# 2          2040                0.0                2.0                5.50
# 3          2160                0.0                2.3                5.94
# 4          2380                0.0                2.0                6.34
#
# ...

# %%
merge = pd.merge(Quality, df, how = 'inner')

# %%
merge.to_csv('Heroes_Quality.csv')
