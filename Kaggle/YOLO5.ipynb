# %% [markdown]
# 0. Check Linkedin
# 1. Yolo
#   1. explanation
#   2. implementation
#   3. fine tune
#
# 2. Nima Project

# %%
# !pip install torch torchvision torchaudio
# !pip install opencv-python
# !pip install git+https://github.com/ultralytics/yolov5.git

# import torch
# model = torch.hub.load('ultralytics/yolov5', 'yolov5s', pretrained=True)

import cv2
img = cv2.imread('/content/bus.jpg')

results = model(img)
results.show()  # Display the image with bounding boxes

results.pandas().xyxy[0] # DataFrame of bounding boxes and labels
# Out:
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# <PIL.Image.Image image mode=RGB size=810x1080>
#          xmin        ymin        xmax        ymax  confidence  class    name
# 0  219.695068  408.034088  346.446625  875.170227    0.864637      0  person
# 1   50.260029  396.812042  237.102448  912.022034    0.849998      0  person
# 2  673.987915  403.471252  809.528198  874.402771    0.820722      0  person
# 3   14.504065  221.097824  809.058472  811.521667    0.791541      5     bus
# 4    0.132493  552.427917   66.660690  875.784973    0.657874      0  person
